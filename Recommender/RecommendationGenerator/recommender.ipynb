# %%
import UserRecommender as ur
from importlib import reload
reload(ur)
# Out:
# <module 'UserRecommender' from 'c:\\Files\\College\\GP\\Repo\\BookRecommendationSystem\\RecommendationGenerator\\UserRecommender.py'>

# %%
rm, mcm = ur.fetchUsers()
# Out:
# (1000000, 5)
# number of unique books:  395468
# number of unique reviews:  999535
# (95258, 5)
# (41432, 5)
# (41432, 5)
# Number of unique users:  1162
# Number of unique books:  493
# (1162, 493)
# (1162, 493)

# %%
ur.recommendUser(rm, mcm)
# Out:
# user mean: 4.962962962962963
# ...
