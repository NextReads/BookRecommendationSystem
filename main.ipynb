# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from DataProcessing.preprocessing import *
from CollabortiveFiltering.collaborative_filtering import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
rating_matrix, mean_centered_matrix = matrix_creation()
# Out:
# (1000000, 5)
# number of unique books:  395468
# number of unique reviews:  999535
# (95258, 5)
# (41432, 5)
# (41432, 5)
# Number of unique users:  1162
# Number of unique books:  493
# (1162, 493)
# (1162, 493)

# %%
user_ID_test = "004d5e96c8a318aeb006af50f8cc949c"
book_ID_test = 1
user_based_prediction = user_based_collaborative_filtering(rating_matrix, mean_centered_matrix, user_ID_test)
item_based_prediction = item_based_collaborative_filtering(rating_matrix, user_ID_test)
average_prediction = average_prediction_collaborative_filtering(item_based_prediction, user_based_prediction, user_ID_test, rating_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23340\3412308093.py in <module>
#       3 user_based_prediction = user_based_collaborative_filtering(rating_matrix, mean_centered_matrix, user_ID_test)
#       4 item_based_prediction = item_based_collaborative_filtering(rating_matrix, user_ID_test)
# ----> 5 average_prediction = average_prediction(item_based_prediction, user_based_prediction, user_ID_test, rating_matrix)
#
# TypeError: 'dict' object is not callable
